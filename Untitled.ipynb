# %%
import sampler

# %%
run -i sampler.py
# Out:
# HELLO

# %%
sampler = Sampler(z_dim = 4, c_dim = 1, scale = 8.0, net_size = 32)

# %%
sampler.generate()
# Out:
# array([[[ 0.99985731],
#         [ 0.9998492 ],
#         [ 0.99983943],
#         ...,
#         [ 0.92838734],
#         [ 0.9303689 ],
#         [ 0.93228376]],
#
#        [[ 0.99985754],
#         [ 0.99984956],
#         [ 0.99983966],
#         ...,
#         [ 0.92738169],
#         [ 0.92942059],
#         [ 0.93138713]],
#
#        [[ 0.99985778],
#         [ 0.99984968],
#         [ 0.9998399 ],
#         ...,
#         [ 0.92636096],
#         [ 0.9284569 ],
#         [ 0.93047768]],
#
#        ...,
#        [[ 0.94352531],
#         [ 0.94390637],
#         [ 0.94428325],
#         ...,
#         [ 0.04756382],
#         [ 0.04784904],
#         [ 0.04812861]],
#
#        [[ 0.94527709],
#         [ 0.94563776],
#         [ 0.9459945 ],
#         ...,
#         [ 0.04747532],
#         [ 0.0477635 ],
#         [ 0.0480468 ]],
#
#        [[ 0.94693357],
#         [ 0.94727391],
#         [ 0.94760996],
#         ...,
#         [ 0.0473879 ],
#         [ 0.04767904],
# ...

# %%
sampler.show_image()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c6d9f407ac7f> in <module>()
# ----> 1 sampler.show_image()
#
# TypeError: show_image() takes exactly 2 arguments (1 given)

# %%
img = sampler.generate()

# %%
sampler.show_image(img)
