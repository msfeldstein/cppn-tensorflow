# %%
# %run -i sampler.py
sampler = Sampler(z_dim = 4, scale = 10.0, net_size = 32)
z1 = sampler.generate_z()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-0f0c08ac4ae8> in <module>()
#       1 get_ipython().magic(u'run -i sampler.py')
# ----> 2 sampler = Sampler(z_dim = 4, scale = 10.0, net_size = 32)
#       3 z1 = sampler.generate_z()
#
# /Users/michael/Source/nets/cppn-tensorflow/sampler.py in __init__(self, z_dim, c_dim, scale, net_size)
#      44 class Sampler():
#      45   def __init__(self, z_dim = 8, c_dim = 1, scale = 10.0, net_size = 32):
# ---> 46     self.cppn = CPPN(z_dim = z_dim, c_dim = c_dim, scale = scale, net_size = net_size)
#      47     self.z = self.generate_z() # saves most recent z here, in case we find a nice image and want the z-vec
#      48   def reinit(self):
#
# /Users/michael/Source/nets/cppn-tensorflow/model.pyc in __init__(self, batch_size, z_dim, c_dim, scale, net_size)
#      50
#      51     # builds the generator network
# ---> 52     self.G = self.generator(x_dim = self.x_dim, y_dim = self.y_dim)
#      53
#      54     self.init()
#
# /Users/michael/Source/nets/cppn-tensorflow/model.pyc in generator(self, x_dim, y_dim, reuse)
#      99     U = fully_connected(z_unroll, net_size, 'g_0_z') + \
#     100         fully_connected(x_unroll, net_size, 'g_0_x', with_bias = False) + \
# --> 101         fully_connected(y_unroll, net_size, 'g_0_y', with_bias = False) + \
#     102         fully_connected(r_unroll, net_size, 'g_0_r', with_bias = False)
#     103
#
# /Users/michael/Source/nets/cppn-tensorflow/ops.pyc in fully_connected(input_, output_size, scope, stddev, with_bias)
#      26     with tf.variable_scope(scope or "FC"):
#      27         matrix = tf.get_variable("Matrix", [shape[1], output_size], tf.float32,
# ---> 28             tf.random_normal_initializer(stddev=stddev))
#      29
#      30         result = tf.matmul(input_, matrix)
#
# /Users/michael/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(name, shape, dtype, initializer, trainable, collections)
#     253   return get_variable_scope().get_variable(_get_default_variable_store(), name,
#     254                                            shape, dtype, initializer,
# --> 255                                            trainable, collections)
#     256
#     257
#
# /Users/michael/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, var_store, name, shape, dtype, initializer, trainable, collections)
#     185     with ops.name_scope(None):
#     186       return var_store.get_variable(full_name, shape, dtype, initializer,
# --> 187                                     self.reuse, trainable, collections)
#     188
#     189
#
# /Users/michael/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, name, shape, dtype, initializer, reuse, trainable, collections)
#      98       if should_check and not reuse:
#      99         raise ValueError("Over-sharing: Variable %s already exists, disallowed."
# --> 100                          " Did you mean to set reuse=True in VarScope?" % name)
#     101       found_var = self._vars[name]
#     102       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Over-sharing: Variable g_0_z/Matrix already exists, disallowed. Did you mean to set reuse=True in VarScope?

# %%
sampler.reinit()
img_data = sampler.generate(z1)
sampler.show_image(img_data)

z2 = sampler.generate_z()
sampler.show_image(sampler.generate(z2))

# %%
sampler.save_anim_gif(z1, z2, 'output.gif', n_frame = 5, duration = 0.04)
# Out:
# processing image  0
# processing image  1
# processing image  2
# processing image  3
# processing image  4
# processing image  5
# processing image  6
# writing gif file...
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Writing Image
# Done

# %%
sampler = Sampler(z_dim = 4, scale = 10.0, net_size = 32)
z1 = sampler.generate_z()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a1622693c70c> in <module>()
# ----> 1 sampler = Sampler(z_dim = 4, scale = 10.0, net_size = 32)
#       2 z1 = sampler.generate_z()
#
# /Users/michael/Source/nets/cppn-tensorflow/sampler.py in __init__(self, z_dim, c_dim, scale, net_size)
#      44 class Sampler():
#      45   def __init__(self, z_dim = 8, c_dim = 1, scale = 10.0, net_size = 32):
# ---> 46     self.cppn = CPPN(z_dim = z_dim, c_dim = c_dim, scale = scale, net_size = net_size)
#      47     self.z = self.generate_z() # saves most recent z here, in case we find a nice image and want the z-vec
#      48   def reinit(self):
#
# /Users/michael/Source/nets/cppn-tensorflow/model.pyc in __init__(self, batch_size, z_dim, c_dim, scale, net_size)
#      50
#      51     # builds the generator network
# ---> 52     self.G = self.generator(x_dim = self.x_dim, y_dim = self.y_dim)
#      53
#      54     self.init()
#
# /Users/michael/Source/nets/cppn-tensorflow/model.pyc in generator(self, x_dim, y_dim, reuse)
#      99     U = fully_connected(z_unroll, net_size, 'g_0_z') + \
#     100         fully_connected(x_unroll, net_size, 'g_0_x', with_bias = False) + \
# --> 101         fully_connected(y_unroll, net_size, 'g_0_y', with_bias = False) + \
#     102         fully_connected(r_unroll, net_size, 'g_0_r', with_bias = False)
#     103
#
# /Users/michael/Source/nets/cppn-tensorflow/ops.pyc in fully_connected(input_, output_size, scope, stddev, with_bias)
#      26     with tf.variable_scope(scope or "FC"):
#      27         matrix = tf.get_variable("Matrix", [shape[1], output_size], tf.float32,
# ---> 28             tf.random_normal_initializer(stddev=stddev))
#      29
#      30         result = tf.matmul(input_, matrix)
#
# /Users/michael/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(name, shape, dtype, initializer, trainable, collections)
#     253   return get_variable_scope().get_variable(_get_default_variable_store(), name,
#     254                                            shape, dtype, initializer,
# --> 255                                            trainable, collections)
#     256
#     257
#
# /Users/michael/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, var_store, name, shape, dtype, initializer, trainable, collections)
#     185     with ops.name_scope(None):
#     186       return var_store.get_variable(full_name, shape, dtype, initializer,
# --> 187                                     self.reuse, trainable, collections)
#     188
#     189
#
# /Users/michael/tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/variable_scope.pyc in get_variable(self, name, shape, dtype, initializer, reuse, trainable, collections)
#      98       if should_check and not reuse:
#      99         raise ValueError("Over-sharing: Variable %s already exists, disallowed."
# --> 100                          " Did you mean to set reuse=True in VarScope?" % name)
#     101       found_var = self._vars[name]
#     102       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Over-sharing: Variable g_0_z/Matrix already exists, disallowed. Did you mean to set reuse=True in VarScope?
